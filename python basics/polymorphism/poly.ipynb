# %%
##base cls

class animal:
    def speak(self):
        return "sound of animal"
    

class dog(animal):
    def speak(self):
        return "woof!"
    
class cat(animal):
    def speak(self):
        return "meow"
    

def speak_animal(animal):
    print(animal.speak())
    
# dog1=dog()

# dog1.speak()

speak_animal(dog)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 24
#      18     print(animal.speak())
#      20 # dog1=dog()
#      21
#      22 # dog1.speak()
# ---> 24 speak_animal(dog)
#
# Cell In[8], line 18, in speak_animal(animal)
#      17 def speak_animal(animal):
# ---> 18     print(animal.speak())
#
# TypeError: dog.speak() missing 1 required positional argument: 'self'

# %%
##polymorphism using functions and methods

##base class

class shape:
    def area(self):
        return "area of the shape"


class rectangle(shape): 
    def __init__(self,width,height):
        self.width=width
        self.heigth=height

    def area(self):
        return self.width * self.heigth
    
class circle(shape):
    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14 * self.radius * self.radius
    
def area_any(shape):
    print(f"the area is {shape.area()}")

area_any(circle(8))
area_any(rectangle(8,7))
# Out:
# the area is 200.96
# the area is 56
